# %% [markdown]
# #<font size = 6><font color = red><b><p style = 'text-align:center'> Markdown in Jupyter Notebook</p></b></font></font>

# %% [markdown]
# In this tuorial you'll learn how to use and write with different markup tags in Jupyter Notebook.
# 1. Heading
# 2. Bold
# 3. Italic
# 4. Bullets
# 5. Numbered Lists
# 6. Mathematical symbols
# 7. Indented Quoting
# 8. Line breaks
# 9. Images
# 10. Colors
# 11. Links

# %% [markdown]
# ## <b><font color = blue>1. Headings</font></b>
# # heading
# ## heading
# ### heading
# #### heading
# ##### heading

# %% [markdown]
# # <b><font color = blue>2. Bold</b></font>
# <b> Senghort is a handsome man</b>
#
# **Senghort**
#
# __Seyha__

# %% [markdown]
# # <b><font color = blue>3. Italic</font></b>

# %% [markdown]
# *Computer Architecture*
#
# _Data Structure and Programming_
#
# *linear algebra*

# %% [markdown]
# # <b><font color = blue>4. Bullets:</font></b>

# %% [markdown]
# <b>There are many subjects for 1st year of department of foundation year  for each following :</b>
# - Calculus I (Analysis I)
# - Calculus II (Analysis II)
# - Informatic (Informatique)
# - Philosophy (philosophie)
# - Management and Marketing (Gestion et Marché)
# - Accountant (Comptabilité)
# - History (L'histoire)
# - Technical Drawning (Dessin Technique)
# - Environment (Environnement)
# - Mechanic (Mécanique)
# - Thermodynamique (Thermodynamique)

# %% [markdown]
# <b>There are many courses syllabus for mathematic in 2nd year in each following :</b>
# * Mathematic:
#   * Differentiation Equation
#     - Jodan Canonical Form
#     - order of ODE
#     - System of ODE
#   * Probability
#     - Simple and Conditional Probability
#     - Discrete random variable
#     - Continuos random variable
#     - Joint probability distribution
#     - Transformation of variables
#   * Linear Algebra
#     * Matrices
#     * Determinant
#     * Vector Space
#     * Linear Transformation
#   * Calculus III
#     + Function of Several Variables
#     + Multiple Integration and Parametric Integration
#     + Vector Analysis

# %% [markdown]
# # <b><font color = blue>4. Numbered List:</font></b>

# %% [markdown]
# <font color = pink>**There are many subjects for 3rd year of department of AMS in each following**:</font>
# > 1. Numerical Analysis
# > 2. Topology & Differential Calculus
# > 3. Linear Regression
# > 4. Minor Project
# > 5. Seminar
# > 6. Programming for Data Science
# > 7. Network
# > 8. France
# > 9. English

# %% [markdown]
# <font color = yellow>**Course Outline of Statistic**</font>
# 1. Descriptive Statistic:
#     + Sub plotting graph
#     + mesurement of central tendency
#       * median
#       * average
#       * mode
#       * midrange
#   c. Dot-plot
#   d. Interquartile
#   e. Outliers
# 2. Point Estimation
#     - unbiased estimator
#     - maximum likelihood method
#     - least-square method
#     - bayesian method
# 3. Confidence Interval
# 4. Hypothesis Testing
# 5. Inference base on two sample
# 6. Analysis of Variance
# 7. Linear Regression

# %% [markdown]
# # <font color = blue><b>5. Mathematical Symbols

# %% [markdown]
# Use this code: $mathematical$ $symbols$
#   - $ 299 $ x $ 288 $
#   - $ 100 $ + $ 20 $
#   - $ 20 $ - $ 34 $
#   - $ 54 $ <= $ 400 $
#   - $ 30 $ ^ $ 64 $
#   - $ 56 $ $/$ $ 56 $

# %% [markdown]
# # <b><font color = blue>6. Indented Quoting:</font></b>

# %% [markdown]
# This is my dog
# > This is my dog
#
# You aer my friend
# > you are my friend

# %% [markdown]
# # <b><font color = blue>7. Break Lines:</font></b>

# %% [markdown]
# This  my grilfriend<br>
# Do you love me ? <br> I fall in love you

# %% [markdown]
# # <b><font color = blue>8. Image</font></b>

# %% [markdown]
# ![Timetable.jpg](attachment:Timetable.jpg)

# %% [markdown]
# ![ITC.jpg](attachment:ITC.jpg)

# %% [markdown]
# ![324668476_882271259590226_8109796477314157978_n.jpg](attachment:324668476_882271259590226_8109796477314157978_n.jpg)

# %% [markdown]
# ![01Sweet.png](attachment:01Sweet.png)

# %% [markdown]
# ![22.png](attachment:22.png)

# %% [markdown]
# # <b><font color = blue>9. Color</font></b>

# %% [markdown]
# <b><font color = blue> mathematic </font><br>
# <font color = red> optimization </font><br>
# <font color = yellow> DiscreteMathematics </font></br>
# <font color = pink> Data Structure </font><br>
# <font color = white> Statistic </font><br>
# <font color = grey> OOP </font><br>
# <font color = green> Database </font></b>

# %% [markdown]
# # <b><font color = blue>10. Links</font></b>

# %% [markdown]
# ==> [click here to youtube](https://www.youtube.com)<br>
# ==> [click here to connect to facebook](https://www.facebook.com)

# %% [markdown]
# # <b><font color = blue>11. Table</font></b>

# %% [markdown]
# | Company | Contact | Country |
# | --- | --- | --- |
# | Amazon | Srey Roth | Germany |
# | Apple | Bona | Mexico |
# | Google | Senghort | Austria |
# | Tesla | Tola | UK |
# | Microsoft | Serey | Canada |

# %% [markdown]
# ## Variable and Datatype

# %%
list = [1,2,3,4,5]
list[0] = 99
list
# Out:
# [99, 2, 3, 4, 5]

# %%
tuple = (1,2,3,4,5)
tuple[2] = 99
tuple
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 tuple = (1,2,3,4,5)
# ----> 2 tuple[2] = 99
#       3 tuple
#
# TypeError: 'tuple' object does not support item assignment

# %%
set = {1,2,3,4,5,6,7}
set.add(89)
set
# Out:
# {1, 2, 3, 4, 5, 6, 7, 89}

# %%
set[0] = 345
set
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 set[0] = 345
#       2 set
#
# TypeError: 'set' object does not support item assignment

# %%
dictionary = {"Name":"Senghort","ID":"e20200706"}
dictionary
# Out:
# {'Name': 'Senghort', 'ID': 'e20200706'}

# %%
dictionary[0] = {"Name":"Seanglong"}
dictionary
# Out:
# {'Name': 'Senghort', 'ID': 'e20200706', 0: {'Name': 'Seanglong'}}

# %%
# Selection, Iteration,
